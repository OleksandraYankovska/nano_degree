# %%
import datetime
import pandas_datareader as pdr
import pandas as pd

api_key='4abcf967da5c06b2b917ea3028e378fab8cc86b3'


tickers = ['FEZ', 'RYCQX', 'LABD', 'ROOF']


start="2020-1-1"
end="2021-7-1"

df = pdr.tiingo.TiingoDailyReader(tickers, start=start, end=end, api_key=api_key)


all_data = df.read()
all_data
# Out:
# /Users/yankovska_o/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   return pd.concat(dfs, self._concat_axis)
#                                     close    high      low     open   volume  \
# symbol date
# FEZ    2020-01-02 00:00:00+00:00  41.2600  41.270  41.0900  41.1300  1725160
#        2020-01-03 00:00:00+00:00  40.7300  40.930  40.6500  40.6500  1267592
#        2020-01-06 00:00:00+00:00  40.8000  40.840  40.5900  40.6100   837542
#        2020-01-07 00:00:00+00:00  40.5700  40.710  40.5500  40.6900  1140467
#        2020-01-08 00:00:00+00:00  40.7700  40.910  40.5500  40.5500  1844136
# ...                                   ...     ...      ...      ...      ...
# ROOF   2021-06-25 00:00:00+00:00  26.4403  26.615  26.4403  26.4600     2784
#        2021-06-28 00:00:00+00:00  26.0563  26.460  25.7200  26.4600     9426
# ...

# %%
import pandas as pd

all_data.to_csv('all_data.csv',  date_format='%Y-%m-%d') 

saved_df = pd.read_csv('all_data.csv', header=0, index_col='date', parse_dates=True)

saved_df
# Out:
#            symbol    close    high      low     open   volume   adjClose  \
# date
# 2020-01-02    FEZ  41.2600  41.270  41.0900  41.1300  1725160  38.103149
# 2020-01-03    FEZ  40.7300  40.930  40.6500  40.6500  1267592  37.613700
# 2020-01-06    FEZ  40.8000  40.840  40.5900  40.6100   837542  37.678344
# 2020-01-07    FEZ  40.5700  40.710  40.5500  40.6900  1140467  37.465942
# 2020-01-08    FEZ  40.7700  40.910  40.5500  40.5500  1844136  37.650640
# ...           ...      ...     ...      ...      ...      ...        ...
# 2021-06-25   ROOF  26.4403  26.615  26.4403  26.4600     2784  25.006013
# 2021-06-28   ROOF  26.0563  26.460  25.7200  26.4600     9426  24.642843
# 2021-06-29   ROOF  25.9629  26.210  25.9629  26.2100     4655  24.554510
# 2021-06-30   ROOF  26.0273  26.170  25.9500  25.9500     3272  24.615416
# 2021-07-01   ROOF  26.2220  26.400  26.0506  26.0506   121708  24.799555
#
#               adjHigh     adjLow    adjOpen  adjVolume  divCash  splitFactor
# date
# ...

# %%
# Import matplotlib
import matplotlib.pyplot as plt 

# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['adjClose']].reset_index().pivot('date', 'symbol', 'adjClose')

# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = daily_close_px.pct_change()

# Plot the distributions
daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))

# Show the resulting plot
plt.show()

# %% [markdown]
# Using Tiingo finance API we can see historical stock prices for multiple tickers 'FEZ', 'RYCQX', 'LABD', 'ROOF'  for the period 1 Jan 2020 to 1 Jul 2021.
# We calculated the daily percentage change of values ‘Adj Close’ for each ticker which you can see on plot diagrams.
# The results with comparative financial statements include the prices of specific assets at different points in time along with the percentage changes over the accompanying time periods.
# According to our results we see that Adj Close for "FEZ" in the period of 1 Jan 2020 to 1 Jul 2021. On the histogram we can see the daily changes, but in order to summarize the most significant results, we will consider the result from the lowest to the highest points. Our data shows that the starting price of 2020-01-02 was 38.1031493497. Then the price slowly moved down and 2020-03-23 reached a minimum value of 23.9444697139. At this stage on the histogram we see a mark of 66% of decrease which we can calculate  using the formula (Old Price - New Price)/Old Price and multiply that number by 100.
# In our case ((38.1031493497 - 22.9444697139) / 22.9444697139)* 100 = 66.0668118497
# After that the price slowly increased and on 1 Jul 2021 and  the stock was  44.9919445752.
# To calculate the percentage change between lowest to the highest points  we use formula
# (44.9919445752. - 38.1031493497)/ 38.1031493497 = 0.157894464 * 100 = 15.7894464
# The Adj Close for "RYCQX" in the period of 1 Jan 2020 to 1 Jul 2021 we see that during this period the price was changing from 2020-01-02  - 81.9844589847 to 2021-07-01 - 45.61.
# Using the same formulas as in the previous example, we will get the percentage changes for each day during this period and finally we can see that percentage changes varied between 0 to 55%.
# The Adj Close for "LABD" in the period of 1 Jan 2020 to 1 Jul 2021 we see that during this period the price was changing from 2020-01-02  - 250.8398422321 to 2021-07-01 - 18.06
# We can conclude that the price has fallen a lot and from the histogram we can see that percentage changes varied between 0 to 37% daily
# The Adj Close for "'ROOF" in the period of 1 Jan 2020 to 1 Jul 2021 we see that during this period the price was changing from 2020-01-02  - 22.5573761168 to 2021-07-01 - 24.7995546312 and from the histogram we can see that percentage changes varied between 0 to 61% daily
