# %%
import pandas_datareader as pdr


api_key='4abcf967da5c06b2b917ea3028e378fab8cc86b3' # <your OWN API token aka key goes here>

start="2020-1-1"
end="2021-1-1"

df = pdr.tiingo.TiingoDailyReader('GOOG', start=start, end=end, api_key=api_key)

goog = df.read()
# Out:
# /Users/yankovska_o/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   return pd.concat(dfs, self._concat_axis)

# %%
import pandas as pd

goog.to_csv('goog_historical.csv',  date_format='%Y-%m-%d') # your fle paths and file name

# # let's read the file that we have just written
saved_df = pd.read_csv('goog_historical.csv', header=0, index_col='date', parse_dates=True)

saved_df
# Out:
#            symbol    close       high       low      open   volume  adjClose  \
# date
# 2020-01-02   GOOG  1367.37  1368.1400  1341.550  1341.550  1406731   68.3685
# 2020-01-03   GOOG  1360.66  1372.5000  1345.544  1347.860  1187006   68.0330
# 2020-01-06   GOOG  1394.21  1396.5000  1350.000  1350.000  1733149   69.7105
# 2020-01-07   GOOG  1393.34  1402.9900  1390.380  1397.940  1511693   69.6670
# 2020-01-08   GOOG  1404.32  1411.5800  1390.840  1392.080  1529177   70.2160
# ...           ...      ...        ...       ...       ...      ...       ...
# 2020-12-24   GOOG  1738.85  1746.0000  1729.110  1735.000   346753   86.9425
# 2020-12-28   GOOG  1776.09  1790.7276  1746.335  1751.635  1390962   88.8045
# 2020-12-29   GOOG  1758.72  1792.4400  1756.090  1787.790  1299395   87.9360
# 2020-12-30   GOOG  1739.52  1765.0950  1725.600  1762.010  1306130   86.9760
# 2020-12-31   GOOG  1751.88  1758.9300  1735.420  1735.420  1012240   87.5940
#
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
goog['close'].plot(grid=True, )
plt.show()

# %%
import pandas_datareader as pdr


api_key='4abcf967da5c06b2b917ea3028e378fab8cc86b3' # <your OWN API token aka key goes here>

start="2020-1-1"
end="2021-1-1"

df = pdr.tiingo.TiingoDailyReader('MSFT', start=start, end=end, api_key=api_key)

msft = df.read()
# Out:
# /Users/yankovska_o/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   return pd.concat(dfs, self._concat_axis)

# %%
import pandas as pd

msft.to_csv('msft_historical.csv',  date_format='%Y-%m-%d') # your fle paths and file name

# # let's read the file that we have just written
saved_df = pd.read_csv('msft_historical.csv', header=0, index_col='date', parse_dates=True)

saved_df
# Out:
#            symbol   close    high     low    open    volume    adjClose  \
# date
# 2020-01-02   MSFT  160.62  160.73  158.33  158.78  22634546  156.573670
# 2020-01-03   MSFT  158.62  159.95  158.06  158.32  21121681  154.624054
# 2020-01-06   MSFT  159.03  159.10  156.51  157.08  20826702  155.023725
# 2020-01-07   MSFT  157.58  159.67  157.32  159.32  21881740  153.610253
# 2020-01-08   MSFT  160.09  160.80  157.95  158.93  27762026  156.057022
# ...           ...     ...     ...     ...     ...       ...         ...
# 2020-12-24   MSFT  222.75  223.61  221.20  221.42  10550572  219.439520
# 2020-12-28   MSFT  224.96  226.03  223.02  224.45  17762701  221.616676
# 2020-12-29   MSFT  224.15  227.18  223.58  226.31  17403213  220.818714
# 2020-12-30   MSFT  221.68  225.63  221.47  225.23  20272337  218.385422
# 2020-12-31   MSFT  222.42  223.00  219.68  221.70  20942132  219.114425
#
#                adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# date
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
msft['close'].plot(grid=True, )
plt.show()
